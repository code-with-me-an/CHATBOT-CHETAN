# %% [markdown]
# <a href="https://colab.research.google.com/github/code-with-me-an/CHATBOT-CHETAN/blob/master/Mahabharata_tiny_LM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Step 1
# ### Loading the Corpus

# %%
# First step is to get the corpus to train on. Let's download the Mahabharata corpus
# !wget https://raw.githubusercontent.com/Theathiestmonk/bhagwat_gita/main/mahabharata.txt
# Out:
# --2026-02-20 03:21:04--  https://raw.githubusercontent.com/Theathiestmonk/bhagwat_gita/main/mahabharata.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1334646 (1.3M) [text/plain]
# Saving to: ‘mahabharata.txt’
#
# mahabharata.txt     100%[===================>]   1.27M  --.-KB/s    in 0.1s
#
# 2026-02-20 03:21:04 (10.0 MB/s) - ‘mahabharata.txt’ saved [1334646/1334646]

# %% [markdown]
# ## Step 2
# ### Reading the file from the system

# %%
# read it in to inspect it
with open('mahabharata.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
print("length of dataset in characters: ", len(text))
# Out:
# length of dataset in characters:  1334646

# %%
# let's look at the first 1000 characters
print(text[:1000])
# Out:
# THE MAHABHARATA
#
# ADI PARVA
#
# SECTION I
#
# Om! Having bowed down to Narayana and Nara, the most exalted male being,
# and also to the goddess Saraswati, must the word Jaya be uttered.
#
# Ugrasrava, the son of Lomaharshana, surnamed Sauti, well-versed in the
# Puranas, bending with humility, one day approached the great sages of
# rigid vows, sitting at their ease, who had attended the twelve years'
# sacrifice of Saunaka, surnamed Kulapati, in the forest of Naimisha. Those
# ascetics, wishing to hear his wonderful narrations, presently began to
# address him who had thus arrived at that recluse abode of the inhabitants
# of the forest of Naimisha. Having been entertained with due respect by
# those holy men, he saluted those Munis (sages) with joined palms, even all
# of them, and inquired about the progress of their asceticism. Then all the
# ascetics being again seated, the son of Lomaharshana humbly occupied the
# ...

# %% [markdown]
# ## Looking at the corpus : Check if it is loaded properly or not

# %% [markdown]
# ## Step 3 : Tokenization

# %% [markdown]
# ### 3.1 Checking How many unique characters (tokens) are there

# %% [markdown]
# ## 3.2 : Creating a tokenization strategy

# %% [markdown]
# ## 3.3 Encoding all text to tokens

# %% [markdown]
# ## Step 4 : Splitting the text into training and validation sets

# %% [markdown]
# ## Step 5 : Feeding the text to the transformer :

# %% [markdown]
# ## Step 5.2 Training in batches for parallelization

# %% [markdown]
# # Step 6 : Input Embeddings : Feeding into Neural Network
